# %% [markdown]
# ### The relative binding Free Energy was computed using MM/GBSA. The molecular mechanic and solvation contributions were computed. The decomposition free energy which deduce the relative contribution of each amino acid to the binding free energy at the H4-H2B inerface was done on AMBER's MMPBSA.py.

# %%
# import MDAnalysis as mda
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# #0.15M

# %% [markdown]
# ### Average Binding Energy dimer (H2A-H2B) - Tetramer (H3-H4) interface for all systems at 0.15 M(Wild-Type=blue, H2BE76K = Red, H4R92T=Green)

# %% [markdown]
# ### Tetramer and one H2A-H2B dimer (the mutated dimer): T-D

# %%
#Tetramer_dimer(one) interface for 0.15M
En=[1,2,3,4,5,6,7]
Energy = ['δG_vdw', 'δG_ele', 'δG_GB', 'δG_nps','δG_MM', 'δG_Solv', 'δG_bind']
wild = [-204.8082 * 4.184, 14236.0438 * 4.184, -14117.9307 * 4.184, -29.8369 * 4.184, 14031.2356 * 4.184, -14147.7676 * 4.184, -116.5320 * 4.184]
E76K= [-188.0274 * 4.184, 15262.3480 * 4.184, -15140.6679 * 4.184, -25.6759 * 4.184, 15074.3206 * 4.184, -15166.3438 * 4.184, -92.0232 * 4.184]
R92T= [-182.7003 * 4.184, 15646.9358 * 4.184, -15530.7722 * 4.184, -25.7016 * 4.184, 15464.2355 * 4.184, -15556.4738 * 4.184, -92.2382 * 4.184]

std1= [ 0.4060 * 4.184, 11.7958 * 4.184, 11.5184 * 4.184, 0.0524 * 4.184, 11.6976 * 4.184, 11.5195 * 4.184, 0.5115 * 4.184]
std2 = [0.3563 * 4.184, 6.8782 * 4.184, 6.7277 * 4.184, 0.0476 * 4.184, 6.9175 * 4.184, 6.7136 * 4.184, 0.5055 * 4.184]
std3 = [0.3848 * 4.184, 14.7842 * 4.184, 14.6639 * 4.184, 0.0506 * 4.184, 14.8271 * 4.184,  14.6536 * 4.184, 0.4554 * 4.184]
E1 = [i-0.3 for i in En]
E2 = [i for i in En]
E3 = [i+0.3 for i in En]

# %%
fig, ax=plt.subplots(figsize=(12, 9))
ax.bar(E1, wild, yerr=std1, color='blue', ec='black', ecolor='black', capsize=5, width=0.3, label="WT")
ax.bar(E2, E76K, yerr=std2, color='red', ec='black', ecolor='black', capsize=5, width=0.3, label="H2BE76K")
ax.bar(E3, R92T, yerr=std3, color='green', ec='black', ecolor='black', capsize=5, width=0.3, label="H4R92T")
ax.set_xticks(En, Energy)
plt.legend(loc='lower left', fontsize=15.5, title='0.15 M', title_fontsize=16.5)
plt.xlabel(r"$\it\bf\Delta G\ Components$", fontsize = 20.0, fontweight="bold")
plt.ylabel(r"$\it\bf\Delta G_{bind} (kJ/mol)$", fontsize = 22.0, fontweight="bold")
plt.tick_params(labelsize=17, pad=1)
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
ax.spines["top"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)
ax.spines["right"].set_linewidth(3)
ax.spines["bottom"].set_linewidth(3)

axIns=fig.add_axes([0.78, 0.65, 0.18, 0.25])
axIns.bar(E1, wild, yerr=std1, color='blue', ec='black', ecolor='black', capsize=5, width=0.3, label="WT")
axIns.bar(E2, E76K, yerr=std2, color='red', ec='black', ecolor='black', capsize=5, width=0.3, label="E76K")
axIns.bar(E3, R92T, yerr=std3, color='green', ec='black', ecolor='black', capsize=5, width=0.3, label="R92T")
axIns.set_xticks(En, Energy, fontsize = 16.0)
axIns.set_xlim([6.5,7.5])
axIns.set_ylim([-500,-350])
plt.tight_layout()

plt.savefig('Energy_Tetramer_dimer_015M.svg',format='svg', dpi=600, transparent=False)
plt.show()
# Out:
# /tmp/ipykernel_306187/1261410676.py:24: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ### Free Energy H2A-H2B dimer-DNA interface (D-DNA)

# %%
###H2A-H2B interface for M
En=[1,2,3,4,5,6,7]
Energy_24M = ['δG_vdw', 'δG_ele', 'δG_GB', 'δG_nps','δG_MM', 'δG_Solv', 'δG_bind']
wild_24M = [-292.4749 * 4.184, -77986.4807 * 4.184, 78071.1739 * 4.184, -39.1029 * 4.184, -78278.9555 * 4.184, 78032.0710 * 4.184, -246.8845 * 4.184]
E76K_24M= [-345.0107 * 4.184, -84587.1884 * 4.184, 84688.2576 * 4.184, -44.0673 * 4.184, -84932.1991 * 4.184, 84644.1904 * 4.184, -288.0087 * 4.184]
R92T_24M= [-284.7103 * 4.184 , -80794.8994 * 4.184, 80870.8533 * 4.184, -37.7369 * 4.184, -81079.6097 * 4.184, 80833.1164 * 4.184,-246.4933 * 4.184]

std1_24M= [1.0696 * 4.184, 32.7629 * 4.184,  32.5725 * 4.184, 0.1542 * 4.184, 33.5891 * 4.184, 32.4440 * 4.184, 1.5484 * 4.184]
std2_24M = [0.9159 * 4.184, 24.1261 * 4.184, 24.2512 * 4.184, 0.0858 * 4.184, 24.6622 * 4.184, 24.1935 * 4.184, 0.8482 * 4.184]
std3_24M = [0.6427 * 4.184, 41.1053 * 4.184, 41.0717 * 4.184,  0.0794 * 4.184, 41.3365 * 4.184, 41.0326 * 4.184, 0.8705 * 4.184]
E1_24M = [i-0.3 for i in En]
E2_24M = [i for i in En]
E3_24M = [i+0.3 for i in En]

# %%
fig, ax=plt.subplots(figsize=(12, 9))
ax.bar(E1_24M, wild_24M, yerr=std1_24M, color='blue', ec='black', ecolor='black', capsize=5, width=0.3, label="WT")
ax.bar(E2_24M, E76K_24M, yerr=std2_24M, color='red', ec='black', ecolor='black', capsize=5, width=0.3, label="H2BE76K")
ax.bar(E3_24M, R92T_24M, yerr=std3_24M, color='green', ec='black', ecolor='black', capsize=5, width=0.3, label="H4R92T")
ax.set_xticks(En, Energy)
plt.legend(loc='upper left', fontsize='large', title='0.15 M', title_fontsize='large')
plt.xlabel(r"$\it\bf\Delta G\ Components$", fontsize = 20.0, fontweight="bold")
plt.ylabel(r"$\it\bf\Delta G_{bind} (kJ/mol)$", fontsize = 22.0, fontweight="bold")
plt.tick_params(labelsize=16, pad=1)
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"

axIns=fig.add_axes([0.80, 0.19, 0.18, 0.27])
axIns.bar(E1_24M, wild_24M, yerr=std1_24M, color='blue', ec='black', ecolor='black', capsize=5, width=0.3, label="WT")
axIns.bar(E2_24M, E76K_24M, yerr=std2_24M, color='red', ec='black', ecolor='black', capsize=5, width=0.3, label="E76K")
axIns.bar(E3_24M, R92T_24M, yerr=std3_24M, color='green', ec='black', ecolor='black', capsize=5, width=0.3, label="R92T")
axIns.set_xticks(En, Energy_24M, fontsize = 14.0)
ax.spines["top"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)
ax.spines["right"].set_linewidth(3)
ax.spines["bottom"].set_linewidth(3)

axIns.set_xlim([6.5,7.5])
axIns.set_ylim([-1230, -900])
plt.tight_layout()

plt.savefig('Energy_dimer_DNA_015M.svg',format='svg', dpi=600, transparent=False)
plt.show()
# Out:
# /tmp/ipykernel_306187/552143088.py:25: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
En=[1,2]
Energy = ['T-D', 'D-DNA']
wild = [ -116.5320 * 4.184, -246.8845 * 4.184]
E76K= [-92.0232 * 4.184, -288.0087 * 4.184]
R92T= [-92.2382 * 4.184, -246.4933 * 4.184]
std1= [0.5115 * 4.184, 1.5484 * 4.184]
std2 = [0.5055 * 4.184, 0.8482 * 4.184]
std3 = [0.4554 * 4.184, 0.8705 * 4.184]
E1 = [i-0.3 for i in En]
E2 = [i for i in En]
E3 = [i+0.3 for i in En]

fig, ax=plt.subplots(figsize=(8, 5))
plt.bar(E1, wild, yerr=std1, color='blue', ec='black', ecolor='black', capsize=5, width=0.3, label="WT")
plt.bar(E2, E76K, yerr=std2, color='red', ec='black', ecolor='black', capsize=5, width=0.3, label="H2BE76K")
plt.bar(E3, R92T, yerr=std3, color='green', ec='black', ecolor='black', capsize=5, width=0.3, label="H4R92T")
plt.xticks(En, Energy, weight='bold', fontsize = 14.0)
plt.ylim([-1230, -300])
ax.spines["top"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)
ax.spines["right"].set_linewidth(3)
ax.spines["bottom"].set_linewidth(3)
#plt.legend(loc='lower right')
plt.xlabel(r"Subunit Interfaces", fontsize = 19.0, fontweight="bold")
plt.ylabel(r"$\it\bf\Delta G_{bind} (kJ/mol)$", fontsize = 20.0, fontweight="bold")
plt.tick_params(labelsize=13, pad=2)
plt.legend(loc=(0.01, 0.015), fontsize=13)
plt.tight_layout()
plt.savefig('Energy_ALL_015M.svg',format='svg', dpi=600, transparent=False)
plt.show()

# %%
En=[1,2]
Energy = ['T-D', 'D-DNA']
wild = [ -116.5320 * 4.184, -246.8845 * 4.184]
E76K= [-92.0232 * 4.184, -288.0087 * 4.184]
R92T= [-92.2382 * 4.184, -246.4933 * 4.184]
std1= [0.5115 * 4.184, 1.5484 * 4.184]
std2 = [0.5055 * 4.184, 0.8482 * 4.184]
std3 = [0.4554 * 4.184, 0.8705 * 4.184]
E1 = [i-0.3 for i in En]
E2 = [i for i in En]
E3 = [i+0.3 for i in En]

fig, ax=plt.subplots(figsize=(5.5, 5))
plt.bar(E1, wild, yerr=std1, color='blue', ec='black', ecolor='black', capsize=5, width=0.3, label="WT")
plt.bar(E2, E76K, yerr=std2, color='red', ec='black', ecolor='black', capsize=5, width=0.3, label="H2BE76K")
plt.bar(E3, R92T, yerr=std3, color='green', ec='black', ecolor='black', capsize=5, width=0.3, label="H4R92T")
plt.xticks(En, Energy, weight='bold', fontsize = 14.0)
plt.ylim([-500,-350])
plt.xlim([0.5,1.5])
ax.spines["top"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)
ax.spines["right"].set_linewidth(3)
ax.spines["bottom"].set_linewidth(3)
#plt.legend(loc='lower right')
plt.xlabel(r"Subunit Interfaces", fontsize = 19.0, fontweight="bold")
plt.ylabel(r"$\it\bf\Delta G_{bind} (kJ/mol)$", fontsize = 20.0, fontweight="bold")
plt.tick_params(labelsize=13, pad=2)
plt.legend(loc=(0.59, 0.02), fontsize=13)
plt.tight_layout()
plt.savefig('OnlyTetramer_dimer_015M.svg',format='svg', dpi=600, transparent=False)
plt.show()

# %%
En=[1,2]
Energy = ['T-D', 'D-DNA']
wild = [ -116.5320 * 4.184, -246.8845 * 4.184]
E76K= [-92.0232 * 4.184, -288.0087 * 4.184]
R92T= [-92.2382 * 4.184, -246.4933 * 4.184]
std1= [0.5115 * 4.184, 1.5484 * 4.184]
std2 = [0.5055 * 4.184, 0.8482 * 4.184]
std3 = [0.4554 * 4.184, 0.8705 * 4.184]
E1 = [i-0.3 for i in En]
E2 = [i for i in En]
E3 = [i+0.3 for i in En]

fig, ax=plt.subplots(figsize=(5.5, 5))
plt.bar(E1, wild, yerr=std1, color='blue', ec='black', ecolor='black', capsize=5, width=0.3, label="WT")
plt.bar(E2, E76K, yerr=std2, color='red', ec='black', ecolor='black', capsize=5, width=0.3, label="H2BE76K")
plt.bar(E3, R92T, yerr=std3, color='green', ec='black', ecolor='black', capsize=5, width=0.3, label="H4R92T")
plt.xticks(En, Energy, weight='bold', fontsize = 14.0)
plt.ylim([-1230, -900])
plt.xlim([1.5,2.5])
ax.spines["top"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)
ax.spines["right"].set_linewidth(3)
ax.spines["bottom"].set_linewidth(3)
#plt.legend(loc='lower right')
plt.xlabel(r"Subunit Interfaces", fontsize = 19.0, fontweight="bold")
plt.ylabel(r"$\it\bf\Delta G_{bind} (kJ/mol)$", fontsize = 20.0, fontweight="bold")
plt.tick_params(labelsize=13, pad=2)
plt.legend(loc=(0.66, 0.02), fontsize=11)
plt.tight_layout()
plt.savefig('Only_dimer_DNA_015M.svg',format='svg', dpi=600, transparent=False)
plt.show()

# %% [markdown]
# ### Tetramer and both H2A-H2B dimer: T-DD

# %%
#Tetramer_dimer(both) interface for 0.15M
En=[1,2,3,4,5,6,7]
Energy = ['δG_vdw', 'δG_ele', 'δG_GB', 'δG_nps','δG_MM', 'δG_Solv', 'δG_bind']
wild = [-387.7688 * 4.184, 30583.0378 * 4.184, -30347.8918 * 4.184, -55.0658 * 4.184, 30195.2689 * 4.184, -30402.9576 * 4.184, -207.6887 * 4.184]
E76K= [-366.9842 * 4.184, 29688.3212 * 4.184, -29436.9632 * 4.184, -50.0161 * 4.184, 29321.3369 * 4.184, -29486.9792 * 4.184, -165.6423 * 4.184]
R92T= [-367.9637 * 4.184, 30324.6725 * 4.184, -30102.6487 * 4.184, -52.6363 * 4.184, 29956.7087 * 4.184, -30155.2851 * 4.184, -198.5763 * 4.184]

std1= [0.6119 * 4.184, 14.4424 * 4.184, 14.1865 * 4.184, 0.0873 * 4.184, 14.2985 * 4.184, 14.1975 * 4.184, 0.7585 * 4.184]
std2 = [0.5011 * 4.184, 16.3837 * 4.184, 16.2758 * 4.184, 0.0629 * 4.184, 16.2971 * 4.184, 16.2829 * 4.184, 0.6665 * 4.184]
std3 = [0.4979 * 4.184, 18.3667 * 4.184, 18.0528 * 4.184, 0.0643 * 4.184, 18.3363 * 4.184,  18.0416 * 4.184, 0.6781 * 4.184]
E1 = [i-0.3 for i in En]
E2 = [i for i in En]
E3 = [i+0.3 for i in En]

# %%
wild = [-207.6887 * 4.184, -541.0954 * 4.184]
E76K= [-165.6423 * 4.184, -539.6957 * 4.184]
R92T= [-198.5763 * 4.184, -508.9940 * 4.184]
std1= [0.7585 * 4.184, 1.8086 * 4.184]
std2 = [0.6665 * 4.184, 1.7021 * 4.184]
std3 = [0.6781 * 4.184, 1.1943 * 4.184]

print(R92T)
print(std3)
# Out:
# [-830.8432392000001, -2129.630896]
# [2.8371704, 4.9969512]

# %%
fig, ax=plt.subplots(figsize=(12, 9))
ax.bar(E1, wild, yerr=std1, color='blue', ec='black', ecolor='black', capsize=5, width=0.3, label="WT")
ax.bar(E2, E76K, yerr=std2, color='red', ec='black', ecolor='black', capsize=5, width=0.3, label="H2BE76K")
ax.bar(E3, R92T, yerr=std3, color='green', ec='black', ecolor='black', capsize=5, width=0.3, label="H4R92T")
ax.set_xticks(En, Energy)
plt.legend(loc='lower left', fontsize=15.5, title='0.15 M', title_fontsize=16.5)
plt.xlabel(r"$\it\bf\Delta G\ Components$", fontsize = 20.0, fontweight="bold")
plt.ylabel(r"$\it\bf\Delta G_{bind} (kJ/mol)$", fontsize = 22.0, fontweight="bold")
plt.tick_params(labelsize=17, pad=1)
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
ax.spines["top"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)
ax.spines["right"].set_linewidth(3)
ax.spines["bottom"].set_linewidth(3)

axIns=fig.add_axes([0.78, 0.65, 0.18, 0.25])
axIns.bar(E1, wild, yerr=std1, color='blue', ec='black', ecolor='black', capsize=5, width=0.3, label="WT")
axIns.bar(E2, E76K, yerr=std2, color='red', ec='black', ecolor='black', capsize=5, width=0.3, label="E76K")
axIns.bar(E3, R92T, yerr=std3, color='green', ec='black', ecolor='black', capsize=5, width=0.3, label="R92T")
axIns.set_xticks(En, Energy, fontsize = 16.0)
axIns.set_xlim([6.5,7.5])
axIns.set_ylim([-900,-600])
plt.tight_layout()

plt.savefig('Energy_Tetramer_dimer_both_015M.svg',format='svg', dpi=600, transparent=False)
plt.show()
# Out:
# /tmp/ipykernel_306187/564041473.py:24: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ### Free Energy H2A_H2B_dimer(both)-DNA interface

# %%
#Dimers(both)_DNA interface at 0.15M (Ignore 2.4M concentration)
En=[1,2,3,4,5,6,7]
Energy_24M = ['δG_vdw', 'δG_ele', 'δG_GB', 'δG_nps','δG_MM', 'δG_Solv', 'δG_bind']
wild_24M = [-649.8880 * 4.184, -158577.8039 * 4.184, 158769.9871 * 4.184, -83.3906 * 4.184, -159227.6919 * 4.184, 158686.5965 * 4.184, -541.0954 * 4.184]
E76K_24M= [-661.5884 * 4.184, -161282.4033 * 4.184, 161489.1306 * 4.184, -84.8346* 4.184, -161943.9917 * 4.184, 161404.2960 * 4.184, -539.6957 * 4.184]
R92T_24M= [-583.1297 * 4.184 , -161063.0969 * 4.184, 161213.4857 * 4.184, -76.2531 * 4.184, -161646.2266 * 4.184, 161137.2326 * 4.184, -508.9940 * 4.184]

std1_24M= [1.1966 * 4.184, 38.9083 * 4.184,  38.6898 * 4.184, 0.1662 * 4.184, 39.7024 * 4.184, 38.5632 * 4.184, 1.8086 * 4.184]
std2_24M = [1.4252 * 4.184, 94.9535 * 4.184, 94.8025 * 4.184, 0.1700 * 4.184, 95.8327 * 4.184, 94.6808 * 4.184, 1.7021 * 4.184]
std3_24M = [0.8541 * 4.184, 39.547 * 4.184, 39.6897 * 4.184,  0.1101 * 4.184, 39.7752 * 4.184, 39.6505 * 4.184, 1.1943 * 4.184]
E1_24M = [i-0.3 for i in En]
E2_24M = [i for i in En]
E3_24M = [i+0.3 for i in En]

# %%
fig, ax=plt.subplots(figsize=(12, 9))
ax.bar(E1_24M, wild_24M, yerr=std1_24M, color='blue', ec='black', ecolor='black', capsize=5, width=0.3, label="WT")
ax.bar(E2_24M, E76K_24M, yerr=std2_24M, color='red', ec='black', ecolor='black', capsize=5, width=0.3, label="H2BE76K")
ax.bar(E3_24M, R92T_24M, yerr=std3_24M, color='green', ec='black', ecolor='black', capsize=5, width=0.3, label="H4R92T")
ax.set_xticks(En, Energy)
plt.legend(loc='upper left', fontsize='large', title='0.15 M', title_fontsize='large')
plt.xlabel(r"$\it\bf\Delta G\ Components$", fontsize = 20.0, fontweight="bold")
plt.ylabel(r"$\it\bf\Delta G_{bind} (kJ/mol)$", fontsize = 22.0, fontweight="bold")
plt.tick_params(labelsize=16, pad=1)
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"

axIns=fig.add_axes([0.80, 0.19, 0.18, 0.27])
axIns.bar(E1_24M, wild_24M, yerr=std1_24M, color='blue', ec='black', ecolor='black', capsize=5, width=0.3, label="WT")
axIns.bar(E2_24M, E76K_24M, yerr=std2_24M, color='red', ec='black', ecolor='black', capsize=5, width=0.3, label="E76K")
axIns.bar(E3_24M, R92T_24M, yerr=std3_24M, color='green', ec='black', ecolor='black', capsize=5, width=0.3, label="R92T")
axIns.set_xticks(En, Energy_24M, fontsize = 14.0)
ax.spines["top"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)
ax.spines["right"].set_linewidth(3)
ax.spines["bottom"].set_linewidth(3)

axIns.set_xlim([6.5,7.5])
axIns.set_ylim([-2300, -2000])
plt.tight_layout()

plt.savefig('Energy_dimer_DNA_both_015M.svg',format='svg', dpi=600, transparent=False)
plt.show()
# Out:
# /tmp/ipykernel_306187/3503212404.py:25: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
En=[1,2]
Energy = ['T_DD', 'DD_DNA']
wild = [-207.6887 * 4.184, -541.0954 * 4.184]
E76K= [-165.6423 * 4.184, -539.6957 * 4.184]
R92T= [-198.5763 * 4.184, -508.9940 * 4.184]
std1= [0.7585 * 4.184, 1.8086 * 4.184]
std2 = [0.6665 * 4.184, 1.7021 * 4.184]
std3 = [0.6781 * 4.184, 1.1943 * 4.184]
E1 = [i-0.3 for i in En]
E2 = [i for i in En]
E3 = [i+0.3 for i in En]

fig, ax=plt.subplots(figsize=(8, 5))
plt.bar(E1, wild, yerr=std1, color='blue', ec='black', ecolor='black', capsize=5, width=0.3, label="WT")
plt.bar(E2, E76K, yerr=std2, color='red', ec='black', ecolor='black', capsize=5, width=0.3, label="H2BE76K")
plt.bar(E3, R92T, yerr=std3, color='green', ec='black', ecolor='black', capsize=5, width=0.3, label="H4R92T")
plt.xticks(En, Energy, weight='bold', fontsize = 14.0)
plt.ylim([-2400, -500])
ax.spines["top"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)
ax.spines["right"].set_linewidth(3)
ax.spines["bottom"].set_linewidth(3)
#plt.legend(loc='lower right')
plt.xlabel(r"Subunit Interfaces", fontsize = 19.0, fontweight="bold")
plt.ylabel(r"$\it\bf\Delta G_{bind} (kJ/mol)$", fontsize = 20.0, fontweight="bold")
plt.tick_params(labelsize=13, pad=2)
plt.legend(loc=(0.01, 0.015), fontsize=13)
plt.tight_layout()
plt.savefig('Energy_ALL_Both_015M.svg',format='svg', dpi=600, transparent=False)
plt.show()

# %%
En=[1,2]
Energy =  ['T_DD', 'DD_DNA']
wild = [-207.6887 * 4.184, -541.0954 * 4.184]
E76K= [-165.6423 * 4.184, -539.6957 * 4.184]
R92T= [-198.5763 * 4.184, -508.9940 * 4.184]
std1= [0.7585 * 4.184, 1.8086 * 4.184]
std2 = [0.6665 * 4.184, 1.7021 * 4.184]
std3 = [0.6781 * 4.184, 1.1943 * 4.184]
E1 = [i-0.3 for i in En]
E2 = [i for i in En]
E3 = [i+0.3 for i in En]

fig, ax=plt.subplots(figsize=(5.5, 5))
plt.bar(E1, wild, yerr=std1, color='blue', ec='black', ecolor='black', capsize=5, width=0.3, label="WT")
plt.bar(E2, E76K, yerr=std2, color='red', ec='black', ecolor='black', capsize=5, width=0.3, label="H2BE76K")
plt.bar(E3, R92T, yerr=std3, color='green', ec='black', ecolor='black', capsize=5, width=0.3, label="H4R92T")
plt.xticks(En, Energy, weight='bold', fontsize = 14.0)
plt.ylim([-1000,-450])
plt.xlim([0.5,1.5])
ax.spines["top"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)
ax.spines["right"].set_linewidth(3)
ax.spines["bottom"].set_linewidth(3)
#plt.legend(loc='lower right')
plt.xlabel(r"Subunit Interfaces", fontsize = 19.0, fontweight="bold")
plt.ylabel(r"$\it\bf\Delta G_{bind} (kJ/mol)$", fontsize = 20.0, fontweight="bold")
plt.tick_params(labelsize=13, pad=2)
plt.legend(loc=(0.59, 0.02), fontsize=13)
plt.tight_layout()
plt.savefig('OnlyTetramer_dimer_both_015M.svg',format='svg', dpi=600, transparent=False)
plt.show()

# %%
En=[1,2]
Energy =  ['T_DD', 'DD_DNA']
wild = [-207.6887 * 4.184, -541.0954 * 4.184]
E76K= [-165.6423 * 4.184, -539.6957 * 4.184]
R92T= [-198.5763 * 4.184, -508.9940 * 4.184]
std1= [0.7585 * 4.184, 1.8086 * 4.184]
std2 = [0.6665 * 4.184, 1.7021 * 4.184]
std3 = [0.6781 * 4.184, 1.1943 * 4.184]
E1 = [i-0.3 for i in En]
E2 = [i for i in En]
E3 = [i+0.3 for i in En]

fig, ax=plt.subplots(figsize=(5.5, 5))
plt.bar(E1, wild, yerr=std1, color='blue', ec='black', ecolor='black', capsize=5, width=0.3, label="WT")
plt.bar(E2, E76K, yerr=std2, color='red', ec='black', ecolor='black', capsize=5, width=0.3, label="H2BE76K")
plt.bar(E3, R92T, yerr=std3, color='green', ec='black', ecolor='black', capsize=5, width=0.3, label="H4R92T")
plt.xticks(En, Energy, weight='bold', fontsize = 14.0)
plt.ylim([-2400,-1700])
plt.xlim([1.5,2.5])
ax.spines["top"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)
ax.spines["right"].set_linewidth(3)
ax.spines["bottom"].set_linewidth(3)
#plt.legend(loc='lower right')
plt.xlabel(r"Subunit Interfaces", fontsize = 19.0, fontweight="bold")
plt.ylabel(r"$\it\bf\Delta G_{bind} (kJ/mol)$", fontsize = 20.0, fontweight="bold")
plt.tick_params(labelsize=13, pad=2)
plt.legend(loc=(0.66, 0.02), fontsize=11)
plt.tight_layout()
plt.savefig('Only_dimer_DNA_both_015M.svg',format='svg', dpi=600, transparent=False)
plt.show()

# %% [markdown]
# ## Total Residue contribution for both H2A-H2B dimers - Tetramer (H3-H4) interface for 1kx5, E76k and R92T at 0.15M¶

# %%
T_1kx5 = pd.read_csv('/home/augustine/Nucleosome_system/1kx5/1kx5_0.15M/MMGBSA/Tetramer_dimer_both/total.dat')
T_E76K = pd.read_csv('/home/augustine/Nucleosome_system/E76K/E76K_0.15M/MMGBSA/Tetramer_dimer_both/total.dat')
T_R92T = pd.read_csv('/home/augustine/Nucleosome_system/R92T/R92T_1/R92T_0.15M/MMGBSA/Tetramer_dimer_both/total.dat')

# %%
T_1kx5
# Out:
#      Residue   Location    E  Std_Dev_E  Std_Err._Mean_E       VDW  \
# 0    ALA   1  R ALA   1  0.0        0.0              0.0 -0.043672
# 1    ARG   2  R ARG   2  0.0        0.0              0.0 -0.063726
# 2    THR   3  R THR   3  0.0        0.0              0.0 -0.116416
# 3    LYS   4  R LYS   4  0.0        0.0              0.0 -0.018828
# 4    GLN   5  R GLN   5  0.0        0.0              0.0 -0.013472
# ..       ...        ...  ...        ...              ...       ...
# 969  TYR 970  L TYR 496  0.0        0.0              0.0 -0.003594
# 970  THR 971  L THR 497  0.0        0.0              0.0 -0.002444
# 971  SER 972  L SER 498  0.0        0.0              0.0 -0.001090
# 972  ALA 973  L ALA 499  0.0        0.0              0.0 -0.000602
# 973  LYS 974  L LYS 500  0.0        0.0              0.0 -0.000932
#
#      Std_Dev_VDW  Std_Err._Mean_VDW         EEE  Std_Dev_EEE  \
# 0       0.031712           0.001418  274.823494     7.403627
# ...

# %%
### Residues with favourable binding free energy contribution of more than 4.184 kJ/mol
Tot1=T_1kx5.loc[T_1kx5['TOTAL'] < -1.0000]
Location=Tot1["Location"]
Tot1
fig, ax=plt.subplots(figsize=(9, 7))
plt.bar(Tot1['Location'], Tot1['TOTAL'], color='blue', label='WT', yerr= Tot1['Std_Err._Mean_TOTAL'], ec='black', ecolor='black', capsize=5)
#Tot1.plot(x='Location', y='TOTAL', kind='bar', color='green', label='Total\n Energy')
plt.axhline(y = -2.5, color = 'black', linestyle = '--')
# plt.ylim(-6.5, 0)
plt.xlabel("Residues", fontsize = 18.0, fontweight="bold")
plt.ylabel(r"$\bf\it\Delta G_{bind(H4-H2B)}$", fontsize = 20.0, fontweight="bold")
# plt.xticks(Tot1['Location'],['H4-T71','H4-Y72','H4-H75','H4-Y88','H4-R92','H2B-L80','H2B-Y83','H2B-E93','H2B-T96','H2B-R99','H2B-L100','H2B-L101'], weight='bold', fontsize = 12.0)
plt.tick_params(labelsize=16, pad=1)
plt.gcf().autofmt_xdate()
plt.legend()
plt.tight_layout()
# plt.savefig("/home/augustine/Nucleosome_system/1kx5/1kx5_0.15M/Codes/Free_Energy/Total_1kx5_24M.svg", format='svg', dpi=600,transparent=False)
plt.show()

Tot2=T_E76K.loc[T_E76K['TOTAL'] < -1.0000]
Location=Tot2["Location"]
Tot2

#Residue contribution to the Free Energy_E76K_0.15M
fig, ax=plt.subplots(figsize=(9, 7))
plt.bar(Tot2['Location'], Tot2['TOTAL'], color='red', label='E76K', yerr= Tot2['Std_Err._Mean_TOTAL'], ec='black', ecolor='black', capsize=5)
#Tot2.plot(x='Location', y='TOTAL', kind='bar', color='red', label='Total\nEnergy')
plt.axhline(y = -2.5, color = 'black', linestyle = '--')
# plt.ylim(-6.5, 0)
plt.xlabel("Residues", fontsize = 18.0, fontweight="bold")
plt.ylabel(r"$\bf\it\Delta G_{bind(H4-H2B)}$", fontsize = 20.0, fontweight="bold")
# plt.xticks(Tot2['Location'],['H4-T71','H4-Y72','H4-H75','H4-Y88','H4-R92','H2B-L80','H2B-Y83','H2B-R92','H2B-E93','H2B-T96','H2B-R99','H2B-L100'], weight='bold', fontsize = 12.0)
plt.tick_params(labelsize=16, pad=1)
plt.gcf().autofmt_xdate()
plt.legend()
plt.tight_layout()
# plt.savefig("/home/augustine/Nucleosome_system/1kx5/1kx5_0.15M/Codes/Free_Energy/Total_E76K_24M.svg", format='svg', dpi=600,transparent=False)
plt.show()

Tot3=T_R92T.loc[T_R92T['TOTAL'] < -1.0000]
Location=Tot3["Location"]
Tot3

#Residue contribution to the Free Energy_R92T_0.15M
fig, ax=plt.subplots(figsize=(9, 7))
plt.bar(Tot3['Location'], Tot3['TOTAL'], color='green', label='R92T', yerr= Tot3['Std_Err._Mean_TOTAL'], ec='black', ecolor='black', capsize=5)
#Tot2.plot(x='Location', y='TOTAL', kind='bar', color='red', label='Total\nEnergy')
plt.axhline(y = -2.5, color = 'black', linestyle = '--')
# plt.ylim(-6.5, 0)
plt.xlabel("Residues", fontsize = 18.0, fontweight="bold")
plt.ylabel(r"$\bf\it\Delta G_{bind(H4-H2B)}$", fontsize = 20.0, fontweight="bold")
# plt.xticks(Tot3['Location'],['H4-T71','H4-Y72','H4-H75','H4-Y88','H4-T92','H2B-L80','H2B-Y83', 'H2B-R92', 'H2B-E93','H2B-T96','H2B-R99','H2B-L100'], weight='bold', fontsize = 12.0)
plt.tick_params(labelsize=16, pad=1)
plt.gcf().autofmt_xdate()
plt.legend()
plt.tight_layout()
# plt.savefig("/home/augustine/Nucleosome_system/1kx5/1kx5_0.15M/Codes/Free_Energy/Total_R92T_24M.svg", format='svg', dpi=600,transparent=False)
plt.show()

# %% [markdown]
# ### Amino acid resiudes whose residue contribution differs by about 4.184 kJ/mol between 1KX5 and H2BE76K

# %%
T_diff3=T_E76K['TOTAL'] - T_1kx5['TOTAL']
TotE_R=T_diff3.loc[T_diff3 > 1.000]
TotE_R2=T_diff3.loc[T_diff3 < -1.000]
frames = [TotE_R, TotE_R2]
Totz = pd.concat(frames)
Totz = Totz.sort_index()
print(Totz)
# print(len(Totz))
#     error = T_E76K['Std_Err._Mean_TOTAL'] + T_R92T['Std_Err._Mean_TOTAL']
# T_err=T_E76K['Std_Err._Mean_TOTAL'] + T_R92T['Std_Err._Mean_TOTAL']
print(T_diff3.loc[[226]])
# Out:
# 226    0.49109
# Name: TOTAL, dtype: float64

# %%
Totx=[3.792859*4.184,-7.431782*4.184,-1.035123*4.184, 1.258864*4.184, 1.500752*4.184,-3.424558*4.184, 1.845883*4.184, 2.107721*4.184, 1.011876*4.184, 2.306012*4.184,-1.085433*4.184, 2.783287*4.184, 1.313924*4.184, 6.304898*4.184, 5.552246*4.184, 1.358801*4.184, 1.250067*4.184,-3.115955*4.184,-1.702910*4.184, 1.157139*4.184, 1.620680*4.184,-2.605674*4.184,-1.195264*4.184,-1.538122*4.184]
Totz=[1.179295*4.184, 4.424077*4.184,-1.046592*4.184,-1.772887*4.184, 1.979629*4.184, 2.181748*4.184,-3.921802*4.184, 1.855945*4.184, 2.067688*4.184, 2.170675*4.184, 1.071789*4.184,-1.795429*4.184, 1.308922*4.184, 1.032918*4.184,-1.253670*4.184, 2.725355*4.184, 1.312307*4.184, 6.278421*4.184, 5.054740*4.184, 1.460278*4.184, 1.690741*4.184, 1.630624*4.184, 1.317756*4.184,-1.255394*4.184, 3.833481*4.184,-1.192250*4.184, 1.235610*4.184, 3.577888*4.184,-1.421795*4.184,-1.575965*4.184, 1.064748*4.184, 2.264627]

# %%
error = T_1kx5['Std_Err._Mean_TOTAL'] + T_E76K['Std_Err._Mean_TOTAL']
print(error.loc[[101]])
positions=[101,104,128,134,209,232,335,349,350,364,425,429,437,444,463,500,502,535,538,592,720,804,811,814,822,823,824,826,827,832,941,947]
T_err=[]
Res_loca= []
for i in range(32):
    Res_loca.append(T_1kx5["Location"].loc[positions[i]])
    pos = (error.loc[positions[i]]) * 4.184
    T_err.append(pos)

print(T_err)
print(Res_loca)
# Out:
# 101    0.015115
# Name: Std_Err._Mean_TOTAL, dtype: float64
# [0.06324263619960886, 0.43343937160217477, 0.319023047527586, 0.3344007269586892, 0.6078655707874265, 0.3868115153047703, 0.691579270971176, 0.20308601251252312, 0.2102910530687025, 0.3027399190977644, 0.4303348318257453, 0.5322737555718501, 0.27778259009569095, 0.2514049618583868, 0.3766103014172061, 0.34817354615578927, 0.11576351931985639, 0.15694715954164007, 0.5708824025550465, 0.9717888556991455, 0.3335780234296453, 0.2082664374812269, 0.6272226109369072, 0.3054622089739764, 0.5457838778523834, 0.19097997704342964, 0.29642996663226107, 0.21030627474503374, 0.42242577880293547, 0.21447693701651468, 0.25063914654739283, 1.1654289872578718]
# ...

# %%
#Difference in Residue contribution to the Free Energy_1kx5_2.4M upon mutation (1kx5 to E76K)
fig, ax=plt.subplots(figsize=(14,5))
Residue = array = np.linspace(1, 32, 32)
# print(Residue)
# Residue=[1,2,3,4]
y_error = [0.06324263619960886, 0.43343937160217477, 0.319023047527586, 0.3344007269586892, 0.6078655707874265, 0.3868115153047703, 0.691579270971176, 0.20308601251252312, 0.2102910530687025, 0.3027399190977644, 0.4303348318257453, 0.5322737555718501, 0.27778259009569095, 0.2514049618583868, 0.3766103014172061, 0.34817354615578927, 0.11576351931985639, 0.15694715954164007, 0.5708824025550465, 0.9717888556991455, 0.3335780234296453, 0.2082664374812269, 0.6272226109369072, 0.3054622089739764, 0.5457838778523834, 0.19097997704342964, 0.29642996663226107, 0.21030627474503374, 0.42242577880293547, 0.21447693701651468, 0.25063914654739283, 1.1654289872578718]
plt.bar(Residue, Totz, color='mediumvioletred', label='WT-H2BE76K', yerr= y_error, ec='black', ecolor='black', capsize=5)
# # plt.ylim(-1.5, 2)
plt.xlabel("Residues", fontsize = 18.0, fontweight="bold")
plt.ylabel(r"$\bf\delta(\Delta G)_{bind}(kJ/mol)$", fontsize = 20.0, fontweight="bold")
plt.xticks(Residue,[r'$\bf H3_{1}-A102$', r'$\bf H3_{1}-E105$', r'$\bf H3_{1}-R129$', r'$\bf H3_{1}-A135$', r'$\bf H4_{1}-H75$', r'$\bf H4_{1}-Y98$', r'$\bf H2A_{1}-R99$', r'$\bf H2A_{1}-S113$', r'$\bf H2A_{1}-V114$', r'$\bf H2A_{1}-K128$', r'$\bf H2B_{1}-S64$', r'$\bf H2B_{1}-D68$', r'$\bf H2B_{1}-E76K$', r'$\bf H2B_{1}-Y83$', r'$\bf H2B_{1}-L102$', r'$\bf H3_{2}-K14$', r'$\bf H3_{2}-P16$', r'$\bf H3_{2}-R49$', r'$\bf H3_{2}-R52$', r'$\bf H3_{2}-D106$', r'$\bf H4_{2}-G99$', r'$\bf H2A_{2}-R81$', r'$\bf H2A_{2}-R88$', r'$\bf H2A_{2}-E91$', r'$\bf H2A_{2}-R99$', r'$\bf H2A_{2}-V100$', r'$\bf H2A_{2}-T101$', r'$\bf H2A_{2}-103$', r'$\bf H2A_{2}-Q104$', r'$\bf H2A_{2}-P109$', r'$\bf H2B_{2}-E93$', r'$\bf H2B_{2}-R99$'])
plt.tick_params(labelsize=11, pad=1)
plt.gcf().autofmt_xdate()
plt.legend(loc='upper right', fontsize=16)
plt.tight_layout()
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
ax.spines["top"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)
ax.spines["right"].set_linewidth(3)
ax.spines["bottom"].set_linewidth(3)
plt.savefig("Tetramer_Dimer_Diff_1kx5_E76K_015M.svg", format='svg', dpi=600,transparent=False)
plt.show()

# %% [markdown]
# ### Amino acid resiudes whose residue contribution differs by about 4.184 kJ/mol between 1KX5 and H4R92T

# %%
T_diff1=T_R92T['TOTAL'] - T_1kx5['TOTAL']
# print(T_diff1)
Tot1_E=T_diff1.loc[T_diff1 > 1.000]
Tot1_E2=T_diff1.loc[T_diff1 < -1.000]
frames = [Tot1_E, Tot1_E2]
Totx = pd.concat(frames)
Totx = Totx.sort_index()
print(Totx)
print(len(Totx))
# Out:
# 104    3.792859
# 105   -7.431782
# 128   -1.035123
# 130    1.258864
# 133    1.500752
# 335   -3.424558
# 349    1.845883
# 350    2.107721
# 353    1.011876
# 364    2.306012
# 429   -1.085433
# 500    2.783287
# 502    1.313924
# 535    6.304898
# 538    5.552246
# 592    1.358801
# 615    1.250067
# 620   -3.115955
# 693   -1.702910
# 696    1.157139
# 811    1.620680
# 818   -2.605674
# 822   -1.195264
# 924   -1.538122
# Name: TOTAL, dtype: float64
# 24

# %%
error = T_1kx5['Std_Err._Mean_TOTAL'] + T_E76K['Std_Err._Mean_TOTAL']
print(error.loc[[101]])
positions=[104,105,128,130,133,335,349,350,353,364,429,500,502,535,538,592,615,620,693,696,811,818,822,924]
T_err=[]
Res_loca= []
for i in range(24):
    Res_loca.append(T_1kx5["Location"].loc[positions[i]])
    pos = (error.loc[positions[i]]) * 4.184
    T_err.append(pos)

print(T_err)
print(Res_loca)
# Out:
# 101    0.015115
# Name: Std_Err._Mean_TOTAL, dtype: float64
# [0.43343937160217477, 0.05515633175091361, 0.319023047527586, 0.03221393336422853, 0.433640723788308, 0.691579270971176, 0.20308601251252312, 0.2102910530687025, 0.2156798102837969, 0.3027399190977644, 0.5322737555718501, 0.34817354615578927, 0.11576351931985639, 0.15694715954164007, 0.5708824025550465, 0.9717888556991455, 0.09282086295057956, 0.6863482195656266, 0.3041510456146611, 0.4435723415792916, 0.6272226109369072, 0.6463917913155566, 0.5457838778523834, 0.3018566737234018]
# ['R GLU 105', 'R ASP 106', 'R ARG 129', 'R ARG 131', 'R ARG 134', 'L ARG  99', 'L SER 113', 'L VAL 114', 'L PRO 117', 'L LYS 128', 'L ASP 193', 'R LYS 251', 'R PRO 253', 'R ARG 286', 'R ARG 289', 'R ASP 343', 'R ARG 366', 'R ARG 371', 'R TYR 444', 'R HIE 447', 'L ARG 338', 'L LYS 345', 'L ARG 349', 'L GLU 451']

# %%
positions_R92T=[104,105,128,130,133,335,349,350,353,364,429,500,502,535,538,592,615,620,693,696,811,818,822,924]
positions_E76K=[101,104,128,134,209,232,335,349,350,364,425,429,437,444,463,500,502,535,538,592,720,804,811,814,822,823,824,826,827,832,941,947]

list_R92T = []
list_E76K = []
for i in range(len(positions_R92T)):
    a = positions_R92T[i] + 295
    list_R92T.append(a)
my_array = np.array(list_R92T)
print(my_array)


for i in range(len(positions_E76K)):
    b = positions_E76K[i] + 295
    list_E76K.append(b)
my_array = np.array(list_E76K)
print(my_array)
# Out:
# [ 399  400  423  425  428  630  644  645  648  659  724  795  797  830
#   833  887  910  915  988  991 1106 1113 1117 1219]
# [ 396  399  423  429  504  527  630  644  645  659  720  724  732  739
#   758  795  797  830  833  887 1015 1099 1106 1109 1117 1118 1119 1121
#  1122 1127 1236 1242]

# %%
#Difference in Residue contribution to the Free Energy_1kx5_2.4M upon mutation (1kx5 to E76K)
fig, ax=plt.subplots(figsize=(14,5))
Residue = array = np.linspace(1, 24, 24)
# print(Residue)
# Residue=[1,2,3,4]
y_error = [0.43343937160217477, 0.05515633175091361, 0.319023047527586, 0.03221393336422853, 0.433640723788308, 0.691579270971176, 0.20308601251252312, 0.2102910530687025, 0.2156798102837969, 0.3027399190977644, 0.5322737555718501, 0.34817354615578927, 0.11576351931985639, 0.15694715954164007, 0.5708824025550465, 0.9717888556991455, 0.09282086295057956, 0.6863482195656266, 0.3041510456146611, 0.4435723415792916, 0.6272226109369072, 0.6463917913155566, 0.5457838778523834, 0.3018566737234018]
plt.bar(Residue, Totx, color='maroon', label='WT_H4R92T', yerr= y_error, ec='black', ecolor='black', capsize=5)
# # plt.ylim(-1.5, 2)
plt.xlabel("Residues", fontsize = 18.0, fontweight="bold")
plt.ylabel(r"$\bf\delta(\Delta G)_{bind}(kJ/mol)$", fontsize = 20.0, fontweight="bold")

plt.xticks(Residue,[r'$\bf H3_{1}-E105$', r'$\bf H3_{1}-D106$', r'$\bf H3_{1}-R129$', r'$\bf H3_{1}-R131$', r'$\bf H3_{1}-R134$', r'$\bf H4_{1}-R99$', r'$\bf H2A_{1}-S113$', r'$\bf H2A_{1}-V114$', r'$\bf H2A_{1}-P117$', r'$\bf H2A_{1}-K128$', r'$\bf H2B_{1}-D68$', r'$\bf H3_{2}-K14$', r'$\bf H3_{2}-P16$', r'$\bf H3_{2}-R49$', r'$\bf H3_{2}-R52$', r'$\bf H3_{2}-D106$', r'$\bf H3_{2}-129$', r'$\bf H3_{2}-R134$', r'$\bf H4_{2}-Y72$', r'$\bf H4_{2}-H75$', r'$\bf H2A_{2}-R88$', r'$\bf H2A_{2}-K95$', r'$\bf H2A_{2}-R99$', r'$\bf H2B_{2}-E76$'])

plt.tick_params(labelsize=11, pad=1)
plt.gcf().autofmt_xdate()
plt.legend(loc='upper right', fontsize=16)
plt.tight_layout()
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
ax.spines["top"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)
ax.spines["right"].set_linewidth(3)
ax.spines["bottom"].set_linewidth(3)
plt.savefig("Tetramer_Dimer_Diff_1kx5_R92T_015M.svg", format='svg', dpi=600,transparent=False)
plt.show()
