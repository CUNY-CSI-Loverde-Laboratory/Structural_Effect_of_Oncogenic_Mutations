# %%
#generate values for data set 1
import pandas as pd
import numpy as np
from scipy.optimize import curve_fit

# Load the CSV file into a pandas DataFrame
df = pd.read_csv(r"C:\Users\kdefo\Desktop\LN\TSA\Processed\WTTSAfinal - Sheet1.csv")

# Extract the data from the first and fourth columns
x_data = df.iloc[:, 0].values
y_data = df.iloc[:, 4].values

# Define the sigmoid function
def sigmoid(x, L, x0, k, b):
    y = L / (1 + np.exp(-k*(x-x0))) + b
    return y

# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 65
x_max = 80
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
params, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = params

# Output the fitted parameters
print("Fitted Parameters:")
print(params)

#print(params([0])) = {Ldimer})
#print(params([1]) = {x0dimer})
#print(params([2]) = {kdimer})
#print(params([3]) = {bdimer})

# Generate x values for plotting the fitted curve
x_fit_curve = np.linspace(min(x_fit), max(x_fit), 1000)
y_fit_curve = sigmoid(x_fit_curve, *params)

# Find y value corresponding to x0 on the fitted curve
y0dim = sigmoid(x0, L, x0, k, b)
x0dim = x0

#generate sigmoidal fit curve for tetramer peak
# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 80
x_max = 90
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
paramstet, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = paramstet

# Output the fitted parameters
print("Fitted Parameters:")
print(paramstet)
# Out:
# Fitted Parameters:
# [ 4.30548577e-01  7.14808320e+01  5.57645387e-01 -1.48007002e-02]
# Fitted Parameters:
# [ 0.57054908 85.42971948  1.03322824  0.43469773]

# %%
#generate values for data set 2
import pandas as pd
import numpy as np
from scipy.optimize import curve_fit

# Load the CSV file into a pandas DataFrame
df = pd.read_csv(r"C:\Users\kdefo\Desktop\LN\TSA\Processed\WTTSAfinal - Sheet1.csv")

# Extract the data from the first and fourth columns
x_data = df.iloc[:, 0].values
y_data = df.iloc[:, 5].values

# Define the sigmoid function
def sigmoid(x, L, x0, k, b):
    y = L / (1 + np.exp(-k*(x-x0))) + b
    return y

# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 65
x_max = 80
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
params, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = params

# Output the fitted parameters
print("Fitted Parameters:")
print(params)

#print(params([0])) = {Ldimer})
#print(params([1]) = {x0dimer})
#print(params([2]) = {kdimer})
#print(params([3]) = {bdimer})

# Generate x values for plotting the fitted curve
x_fit_curve = np.linspace(min(x_fit), max(x_fit), 1000)
y_fit_curve = sigmoid(x_fit_curve, *params)

# Find y value corresponding to x0 on the fitted curve
y0dim = sigmoid(x0, L, x0, k, b)
x0dim = x0

#generate sigmoidal fit curve for tetramer peak
# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 80
x_max = 90
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
paramstet, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = paramstet

# Output the fitted parameters
print("Fitted Parameters:")
print(paramstet)
# Out:
# Fitted Parameters:
# [ 4.50120531e-01  7.14900848e+01  4.90841345e-01 -2.83738885e-02]
# Fitted Parameters:
# [ 0.55204015 85.46420507  1.32459522  0.4383317 ]

# %%
#generate values for data set 3
import pandas as pd
import numpy as np
from scipy.optimize import curve_fit

# Load the CSV file into a pandas DataFrame
df = pd.read_csv(r"C:\Users\kdefo\Desktop\LN\TSA\Processed\WTTSAfinal - Sheet1.csv")

# Extract the data from the first and fourth columns
x_data = df.iloc[:, 0].values
y_data = df.iloc[:, 6].values

# Define the sigmoid function
def sigmoid(x, L, x0, k, b):
    y = L / (1 + np.exp(-k*(x-x0))) + b
    return y

# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 65
x_max = 80
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
params, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = params

# Output the fitted parameters
print("Fitted Parameters:")
print(params)

#print(params([0])) = {Ldimer})
#print(params([1]) = {x0dimer})
#print(params([2]) = {kdimer})
#print(params([3]) = {bdimer})

# Generate x values for plotting the fitted curve
x_fit_curve = np.linspace(min(x_fit), max(x_fit), 1000)
y_fit_curve = sigmoid(x_fit_curve, *params)

# Find y value corresponding to x0 on the fitted curve
y0dim = sigmoid(x0, L, x0, k, b)
x0dim = x0

#generate sigmoidal fit curve for tetramer peak
# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 80
x_max = 90
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
paramstet, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = paramstet

# Output the fitted parameters
print("Fitted Parameters:")
print(paramstet)
# Out:
# Fitted Parameters:
# [ 4.27373970e-01  7.16516069e+01  5.07474928e-01 -2.27305301e-02]
# Fitted Parameters:
# [ 0.5888057  85.43910681  1.03479834  0.41626291]

# %%
#generate error for dimer melting
from scipy.stats import sem
dimermelt = [7.14808320e+01, 7.14900848e+01, 7.16516069e+01]

print(sem(dimermelt))
# Out:
# 0.05544720690603858

# %%
#generate values and plot for WT average data
import pandas as pd
import numpy as np
from scipy.optimize import curve_fit

# Load the CSV file into a pandas DataFrame
df = pd.read_csv(r"C:\Users\kdefo\Desktop\LN\TSA\Processed\WTTSAfinal - Sheet1.csv")

# Extract the data from the first and fourth columns
x_data = df.iloc[:, 0].values
y_data = df.iloc[:, 7].values

# Define the sigmoid function
def sigmoid(x, L, x0, k, b):
    y = L / (1 + np.exp(-k*(x-x0))) + b
    return y

# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 65
x_max = 80
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
params, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = params

# Output the fitted parameters
print("Fitted Parameters:")
print(params)

#print(params([0])) = {Ldimer})
#print(params([1]) = {x0dimer})
#print(params([2]) = {kdimer})
#print(params([3]) = {bdimer})

# Generate x values for plotting the fitted curve
x_fit_curve = np.linspace(min(x_fit), max(x_fit), 1000)
y_fit_curve = sigmoid(x_fit_curve, *params)

# Find y value corresponding to x0 on the fitted curve
y0dim = sigmoid(x0, L, x0, k, b)
x0dim = x0

#generate sigmoidal fit curve for tetramer peak
# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 80
x_max = 90
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
paramstet, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = paramstet

# Output the fitted parameters
print("Fitted Parameters:")
print(paramstet)

# Generate x values for plotting the fitted curve
x_fit_curvetet = np.linspace(min(x_fit), max(x_fit), 1000)
y_fit_curvetet = sigmoid(x_fit_curvetet, *paramstet)


import matplotlib.pyplot as plt

fig, ax=plt.subplots(figsize=(6.5, 5))

x_dat = x_data[(x_data >= 50) & (x_data <= 95)]
y_dat = y_data[(x_data >= 50) & (x_data <= 95)]

#plot of fit for dimer
plt.scatter(x_dat, y_dat, marker ='o', color='b')
plt.plot(x_fit_curve, y_fit_curve, 'b-', '-')

#plot of fit for tetramer
plt.scatter(x_dat, y_dat, marker ='o', color='b')
plt.plot(x_fit_curvetet, y_fit_curvetet, 'b-', '-')

# Find y value corresponding to x0 on the fitted curve
y0 = sigmoid(x0, L, x0, k, b)

# Plot marker for x0
plt.plot()
#plt.legend(x0, y0, 'r.', label='T$_m$ = 75.5', loc='upper right', fontsize=13, title_fontsize=14)
plt.xlabel('Temperature (°C)', fontsize = 16, fontweight="bold")
plt.ylabel('Normalized Fluorescence', fontsize = 18, fontweight="bold")

# Set y-axis limits and tick locations
plt.ylim(0, 1)  # Adjust the y-axis limits as needed
ytick_values = np.arange(0.2, 1.1, 0.2)

plt.yticks(ytick_values, [f'{val:.1f}' for val in ytick_values])  # Set the y-axis tick locations and labels
plt.tick_params(labelsize=14.5, pad=1)
ax.spines["top"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)
ax.spines["right"].set_linewidth(3)
ax.spines["bottom"].set_linewidth(3)

plt.tight_layout()
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"

plt.plot(title='WT')
plt.plot(x0dim, y0dim, 'k.', label='T$_m$ dimer  = 71.5°C', markersize=15)
plt.plot(x0, y0, 'k.', label='T$_m$ tetramer  = 85.4°C', markersize=15)

#plt.plot(x_dat, y_dat, label='\nWT')
#plt.plot(x0, y0, label='\nT$_m$ = 65.2')

plt.legend(loc='upper left', fontsize=13, title_fontsize=14, title='WT')

#plt.title('WT NCP')
plt.xlim(60, 95)  # Set x-axis limits
plt.show()
# Out:
# Fitted Parameters:
# [ 4.35818467e-01  7.15380527e+01  5.17332962e-01 -2.19154384e-02]
# Fitted Parameters:
# [ 0.56945745 85.44746122  1.11979275  0.43041838]

# %%
#generate values for data set 1
import pandas as pd
import numpy as np
from scipy.optimize import curve_fit

# Load the CSV file into a pandas DataFrame
df = pd.read_csv(r"C:\Users\kdefo\Desktop\LN\TSA\Processed\E76KTSAfinal - Sheet1.csv")

# Extract the data from the first and fourth columns
x_data = df.iloc[:, 0].values
y_data = df.iloc[:, 4].values

# Define the sigmoid function
def sigmoid(x, L, x0, k, b):
    y = L / (1 + np.exp(-k*(x-x0))) + b
    return y

# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 65
x_max = 80
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
params, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = params

# Output the fitted parameters
print("Fitted Parameters:")
print(params)

#print(params([0])) = {Ldimer})
#print(params([1]) = {x0dimer})
#print(params([2]) = {kdimer})
#print(params([3]) = {bdimer})

# Generate x values for plotting the fitted curve
x_fit_curve = np.linspace(min(x_fit), max(x_fit), 1000)
y_fit_curve = sigmoid(x_fit_curve, *params)

# Find y value corresponding to x0 on the fitted curve
y0dim = sigmoid(x0, L, x0, k, b)
x0dim = x0

#generate sigmoidal fit curve for tetramer peak
# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 80
x_max = 90
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
paramstet, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = paramstet

# Output the fitted parameters
print("Fitted Parameters:")
print(paramstet)
# Out:
# Fitted Parameters:
# [3.89723734e-01 6.68912596e+01 1.00445250e+00 5.89325120e-02]
# Fitted Parameters:
# [ 0.43486395 85.37704643  4.13894943  0.48554401]

# %%
#generate values for data set 1
import pandas as pd
import numpy as np
from scipy.optimize import curve_fit

# Load the CSV file into a pandas DataFrame
df = pd.read_csv(r"C:\Users\kdefo\Desktop\LN\TSA\Processed\E76KTSAfinal - Sheet1.csv")

# Extract the data from the first and fourth columns
x_data = df.iloc[:, 0].values
y_data = df.iloc[:, 5].values

# Define the sigmoid function
def sigmoid(x, L, x0, k, b):
    y = L / (1 + np.exp(-k*(x-x0))) + b
    return y

# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 65
x_max = 80
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
params, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = params

# Output the fitted parameters
print("Fitted Parameters:")
print(params)

#print(params([0])) = {Ldimer})
#print(params([1]) = {x0dimer})
#print(params([2]) = {kdimer})
#print(params([3]) = {bdimer})

# Generate x values for plotting the fitted curve
x_fit_curve = np.linspace(min(x_fit), max(x_fit), 1000)
y_fit_curve = sigmoid(x_fit_curve, *params)

# Find y value corresponding to x0 on the fitted curve
y0dim = sigmoid(x0, L, x0, k, b)
x0dim = x0

#generate sigmoidal fit curve for tetramer peak
# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 80
x_max = 90
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
paramstet, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = paramstet

# Output the fitted parameters
print("Fitted Parameters:")
print(paramstet)
# Out:
# Fitted Parameters:
# [ 0.4314493  66.81634992  1.11508041  0.07243668]
# Fitted Parameters:
# [ 0.4549791  85.27757353  5.12628594  0.54305875]

# %%
#generate values for data set 1
import pandas as pd
import numpy as np
from scipy.optimize import curve_fit

# Load the CSV file into a pandas DataFrame
df = pd.read_csv(r"C:\Users\kdefo\Desktop\LN\TSA\Processed\E76KTSAfinal - Sheet1.csv")

# Extract the data from the first and fourth columns
x_data = df.iloc[:, 0].values
y_data = df.iloc[:, 6].values

# Define the sigmoid function
def sigmoid(x, L, x0, k, b):
    y = L / (1 + np.exp(-k*(x-x0))) + b
    return y

# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 65
x_max = 80
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
params, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = params

# Output the fitted parameters
print("Fitted Parameters:")
print(params)

#print(params([0])) = {Ldimer})
#print(params([1]) = {x0dimer})
#print(params([2]) = {kdimer})
#print(params([3]) = {bdimer})

# Generate x values for plotting the fitted curve
x_fit_curve = np.linspace(min(x_fit), max(x_fit), 1000)
y_fit_curve = sigmoid(x_fit_curve, *params)

# Find y value corresponding to x0 on the fitted curve
y0dim = sigmoid(x0, L, x0, k, b)
x0dim = x0

#generate sigmoidal fit curve for tetramer peak
# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 80
x_max = 90
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
paramstet, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = paramstet

# Output the fitted parameters
print("Fitted Parameters:")
print(paramstet)
# Out:
# Fitted Parameters:
# [4.57101341e-01 6.61148044e+01 8.18895417e-01 1.48502174e-02]
# Fitted Parameters:
# [ 0.50256109 85.21102009  5.07569579  0.4810073 ]

# %%
#generate error for dimer melting
from scipy.stats import sem
dimermeltE76K = [6.68912596e+01, 66.81634992, 6.61148044e+01]

print(sem(dimermeltE76K))
# Out:
# 0.24728079567757355

# %%
import pandas as pd
import numpy as np
from scipy.optimize import curve_fit

# Load the CSV file into a pandas DataFrame
df = pd.read_csv(r"C:\Users\kdefo\Desktop\LN\TSA\Processed\E76KTSAfinal - Sheet1.csv")

# Extract the data from the first and fourth columns
x_data = df.iloc[:, 0].values
y_data = df.iloc[:, 7].values

# Define the sigmoid function
def sigmoid(x, L, x0, k, b):
    y = L / (1 + np.exp(-k*(x-x0))) + b
    return y

# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 60
x_max = 75
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
params, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = params

# Output the fitted parameters
print("Fitted Parameters:")
print(params)

#print(params([0])) = {Ldimer})
#print(params([1]) = {x0dimer})
#print(params([2]) = {kdimer})
#print(params([3]) = {bdimer})

# Generate x values for plotting the fitted curve
x_fit_curve = np.linspace(min(x_fit), max(x_fit), 1000)
y_fit_curve = sigmoid(x_fit_curve, *params)

# Find y value corresponding to x0 on the fitted curve
y0dim = sigmoid(x0, L, x0, k, b)
x0dim = x0

#generate sigmoidal fit curve for tetramer peak
# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 80
x_max = 90
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
paramstet, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = paramstet

# Output the fitted parameters
print("Fitted Parameters:")
print(paramstet)

# Generate x values for plotting the fitted curve
x_fit_curvetet = np.linspace(min(x_fit), max(x_fit), 1000)
y_fit_curvetet = sigmoid(x_fit_curvetet, *paramstet)


import matplotlib.pyplot as plt

fig, ax=plt.subplots(figsize=(6.5, 5))

x_dat = x_data[(x_data >= 50) & (x_data <= 95)]
y_dat = y_data[(x_data >= 50) & (x_data <= 95)]

#plot of fit for dimer
plt.scatter(x_dat, y_dat, marker ='o', color='r')
plt.plot(x_fit_curve, y_fit_curve, 'r-', '-')

#plot of fit for tetramer
plt.scatter(x_dat, y_dat, marker ='o', color='r')
plt.plot(x_fit_curvetet, y_fit_curvetet, 'r-', '-')

# Find y value corresponding to x0 on the fitted curve
y0 = sigmoid(x0, L, x0, k, b)

# Plot marker for x0
plt.plot()
#plt.legend(x0, y0, 'r.', label='T$_m$ = 75.5', loc='upper right', fontsize=13, title_fontsize=14)
plt.xlabel('Temperature (°C)', fontsize = 16, fontweight="bold")
plt.ylabel('Normalized Fluorescence', fontsize = 18, fontweight="bold")

# Set y-axis limits and tick locations
plt.ylim(0, 1)  # Adjust the y-axis limits as needed
ytick_values = np.arange(0.2, 1.1, 0.2)

plt.yticks(ytick_values, [f'{val:.1f}' for val in ytick_values])  # Set the y-axis tick locations and labels
plt.tick_params(labelsize=14.5, pad=1)
ax.spines["top"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)
ax.spines["right"].set_linewidth(3)
ax.spines["bottom"].set_linewidth(3)

plt.tight_layout()
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"

plt.plot(title='E76K')
plt.plot(x0dim, y0dim, 'k.', label='T$_m$ dimer  = 66.3°C', markersize=15)
plt.plot(x0, y0, 'k.', label='T$_m$ tetramer  = 85.3°C', markersize=15)

#plt.plot(x_dat, y_dat, label='\nWT')
#plt.plot(x0, y0, label='\nT$_m$ = 65.2')

plt.legend(loc='upper left', fontsize=13, title_fontsize=14, title='E76K')

#plt.title('WT NCP')
plt.xlim(60, 95)  # Set x-axis limits
plt.show()
# Out:
# Fitted Parameters:
# [4.74796423e-01 6.63493061e+01 8.53125652e-01 2.75849205e-03]
# Fitted Parameters:
# [ 0.46416468 85.28783201  4.60305592  0.50315869]

# %%
#generate values for data set 1
import pandas as pd
import numpy as np
from scipy.optimize import curve_fit

# Load the CSV file into a pandas DataFrame
df = pd.read_csv(r"C:\Users\kdefo\Desktop\LN\TSA\Processed\R92TTSAfinal - Sheet1.csv")

# Extract the data from the first and fourth columns
x_data = df.iloc[:, 0].values
y_data = df.iloc[:, 4].values

# Define the sigmoid function
def sigmoid(x, L, x0, k, b):
    y = L / (1 + np.exp(-k*(x-x0))) + b
    return y

# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 65
x_max = 80
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
params, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = params

# Output the fitted parameters
print("Fitted Parameters:")
print(params)

#print(params([0])) = {Ldimer})
#print(params([1]) = {x0dimer})
#print(params([2]) = {kdimer})
#print(params([3]) = {bdimer})

# Generate x values for plotting the fitted curve
x_fit_curve = np.linspace(min(x_fit), max(x_fit), 1000)
y_fit_curve = sigmoid(x_fit_curve, *params)

# Find y value corresponding to x0 on the fitted curve
y0dim = sigmoid(x0, L, x0, k, b)
x0dim = x0

#generate sigmoidal fit curve for tetramer peak
# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 80
x_max = 90
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
paramstet, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = paramstet

# Output the fitted parameters
print("Fitted Parameters:")
print(paramstet)
# Out:
# Fitted Parameters:
# [ 5.09542207e-01  7.01746652e+01  5.60657395e-01 -6.23209812e-04]
# Fitted Parameters:
# [ 0.47921941 84.51866147  2.18987985  0.51800358]

# %%
#generate values for data set 1
import pandas as pd
import numpy as np
from scipy.optimize import curve_fit

# Load the CSV file into a pandas DataFrame
df = pd.read_csv(r"C:\Users\kdefo\Desktop\LN\TSA\Processed\R92TTSAfinal - Sheet1.csv")

# Extract the data from the first and fourth columns
x_data = df.iloc[:, 0].values
y_data = df.iloc[:, 5].values

# Define the sigmoid function
def sigmoid(x, L, x0, k, b):
    y = L / (1 + np.exp(-k*(x-x0))) + b
    return y

# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 65
x_max = 80
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
params, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = params

# Output the fitted parameters
print("Fitted Parameters:")
print(params)

#print(params([0])) = {Ldimer})
#print(params([1]) = {x0dimer})
#print(params([2]) = {kdimer})
#print(params([3]) = {bdimer})

# Generate x values for plotting the fitted curve
x_fit_curve = np.linspace(min(x_fit), max(x_fit), 1000)
y_fit_curve = sigmoid(x_fit_curve, *params)

# Find y value corresponding to x0 on the fitted curve
y0dim = sigmoid(x0, L, x0, k, b)
x0dim = x0

#generate sigmoidal fit curve for tetramer peak
# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 80
x_max = 90
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
paramstet, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = paramstet

# Output the fitted parameters
print("Fitted Parameters:")
print(paramstet)
# Out:
# Fitted Parameters:
# [ 5.32568873e-01  7.02572448e+01  4.46986007e-01 -3.64233118e-02]
# Fitted Parameters:
# [ 0.4536344  84.87265746  1.28316941  0.52999895]

# %%
#generate values for data set 1
import pandas as pd
import numpy as np
from scipy.optimize import curve_fit

# Load the CSV file into a pandas DataFrame
df = pd.read_csv(r"C:\Users\kdefo\Desktop\LN\TSA\Processed\R92TTSAfinal - Sheet1.csv")

# Extract the data from the first and fourth columns
x_data = df.iloc[:, 0].values
y_data = df.iloc[:, 6].values

# Define the sigmoid function
def sigmoid(x, L, x0, k, b):
    y = L / (1 + np.exp(-k*(x-x0))) + b
    return y

# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 65
x_max = 80
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
params, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = params

# Output the fitted parameters
print("Fitted Parameters:")
print(params)

#print(params([0])) = {Ldimer})
#print(params([1]) = {x0dimer})
#print(params([2]) = {kdimer})
#print(params([3]) = {bdimer})

# Generate x values for plotting the fitted curve
x_fit_curve = np.linspace(min(x_fit), max(x_fit), 1000)
y_fit_curve = sigmoid(x_fit_curve, *params)

# Find y value corresponding to x0 on the fitted curve
y0dim = sigmoid(x0, L, x0, k, b)
x0dim = x0

#generate sigmoidal fit curve for tetramer peak
# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 80
x_max = 90
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
paramstet, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = paramstet

# Output the fitted parameters
print("Fitted Parameters:")
print(paramstet)
# Out:
# Fitted Parameters:
# [ 5.09542207e-01  7.01746652e+01  5.60657395e-01 -6.23209812e-04]
# Fitted Parameters:
# [ 0.47921941 84.51866147  2.18987985  0.51800358]

# %%
#generate error for dimer melting
from scipy.stats import sem
dimermeltR92T = [7.01746652e+01, 7.02572448e+01, 7.01746652e+01]

print(sem(dimermeltR92T))
# Out:
# 0.027526533333329443

# %%
import pandas as pd
import numpy as np
from scipy.optimize import curve_fit

# Load the CSV file into a pandas DataFrame
df = pd.read_csv(r"C:\Users\kdefo\Desktop\LN\TSA\Processed\R92TTSAfinal - Sheet1.csv")

# Extract the data from the first and fourth columns
x_data = df.iloc[:, 0].values
y_data = df.iloc[:, 7].values

# Define the sigmoid function
def sigmoid(x, L, x0, k, b):
    y = L / (1 + np.exp(-k*(x-x0))) + b
    return y

# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 60
x_max = 80
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
params, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = params

# Output the fitted parameters
print("Fitted Parameters:")
print(params)

#print(params([0])) = {Ldimer})
#print(params([1]) = {x0dimer})
#print(params([2]) = {kdimer})
#print(params([3]) = {bdimer})

# Generate x values for plotting the fitted curve
x_fit_curve = np.linspace(min(x_fit), max(x_fit), 1000)
y_fit_curve = sigmoid(x_fit_curve, *params)

# Find y value corresponding to x0 on the fitted curve
y0dim = sigmoid(x0, L, x0, k, b)
x0dim = x0

#generate sigmoidal fit curve for tetramer peak
# Fit the data to the sigmoid function
# Define the x-axis limits for fitting
x_min = 80
x_max = 90
x_fit = x_data[(x_data >= x_min) & (x_data <= x_max)]
y_fit = y_data[(x_data >= x_min) & (x_data <= x_max)]

# Perform curve fitting
p0 = [max(y_fit), np.median(x_fit), 1, min(y_fit)] # Initial guess for the parameters
paramstet, covariance = curve_fit(sigmoid, x_fit, y_fit, p0=p0)

# Extract the fitted parameters
L, x0, k, b = paramstet

# Output the fitted parameters
print("Fitted Parameters:")
print(paramstet)

# Generate x values for plotting the fitted curve
x_fit_curvetet = np.linspace(min(x_fit), max(x_fit), 1000)
y_fit_curvetet = sigmoid(x_fit_curvetet, *paramstet)


import matplotlib.pyplot as plt

fig, ax=plt.subplots(figsize=(6.5, 5))

x_dat = x_data[(x_data >= 50) & (x_data <= 95)]
y_dat = y_data[(x_data >= 50) & (x_data <= 95)]

#plot of fit for dimer
plt.scatter(x_dat, y_dat, marker ='o', color='g')
plt.plot(x_fit_curve, y_fit_curve, 'g-', '-')

#plot of fit for tetramer
plt.scatter(x_dat, y_dat, marker ='o', color='g')
plt.plot(x_fit_curvetet, y_fit_curvetet, 'g-', '-')

# Find y value corresponding to x0 on the fitted curve
y0 = sigmoid(x0, L, x0, k, b)

# Plot marker for x0
plt.plot()
#plt.legend(x0, y0, 'r.', label='T$_m$ = 75.5', loc='upper right', fontsize=13, title_fontsize=14)
plt.xlabel('Temperature (°C)', fontsize = 16, fontweight="bold")
plt.ylabel('Normalized Fluorescence', fontsize = 18, fontweight="bold")

# Set y-axis limits and tick locations
plt.ylim(0, 1)  # Adjust the y-axis limits as needed
ytick_values = np.arange(0.2, 1.1, 0.2)

plt.yticks(ytick_values, [f'{val:.1f}' for val in ytick_values])  # Set the y-axis tick locations and labels
plt.tick_params(labelsize=14.5, pad=1)
ax.spines["top"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)
ax.spines["right"].set_linewidth(3)
ax.spines["bottom"].set_linewidth(3)

plt.tight_layout()
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"

plt.plot(title='E76K')
plt.plot(x0dim, y0dim, 'k.', label='T$_m$ dimer  = 70.3°C', markersize=15)
plt.plot(x0, y0, 'k.', label='T$_m$ tetramer  = 84.6°C', markersize=15)

#plt.plot(x_dat, y_dat, label='\nWT')
#plt.plot(x0, y0, label='\nT$_m$ = 65.2')

plt.legend(loc='upper left', fontsize=13, title_fontsize=14, title='R92T')

#plt.title('WT NCP')
plt.xlim(60, 95)  # Set x-axis limits
plt.show()
# Out:
# Fitted Parameters:
# [4.95919329e-01 7.03258621e+01 5.60550187e-01 4.31289541e-03]
# Fitted Parameters:
# [ 0.46810369 84.61421311  1.81394668  0.52260614]

# %%
fig, ax=plt.subplots(figsize=(7, 6))
Residue=[1,2,3]
y_error = [0.05544720690603858, 0.24728079567757355 ,0.027526533333329443]
y = [71.5, 66.3 , 70.3]
color = ['blue', 'red', 'green']
label = ['WT', 'E76K', 'R92T']
#Totx = [-0.567443, 0.695601, 0.399026, 0.443620, 1.897195, 0.632444, 0.818218, -0.522891]
plt.bar(Residue, y, yerr= y_error, color=color, label=label,ec='black', ecolor='black', capsize=5)
plt.ylim(65, 72)
plt.xlabel("Systems", fontsize = 21.0, fontweight="bold")
plt.ylabel(r"$\bf\it{Melting\ Temperature\ (°C)}$", fontsize = 22.0, fontweight="bold")
plt.xticks(Residue,['WT', 'E76K', 'R92T'])
plt.tick_params(labelsize=15, pad=1)
# plt.gcf().autofmt_xdate()
ax.spines["top"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)
ax.spines["right"].set_linewidth(3)
ax.spines["bottom"].set_linewidth(3)
# plt.legend(loc='upper right', fontsize=13, title='Systems', title_fontsize=14)
plt.tight_layout()
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
